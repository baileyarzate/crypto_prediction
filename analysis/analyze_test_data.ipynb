# %%
import pandas as pd
interest = pd.read_csv(r'C:\Users\baile\Documents\Artificial Intelligence\BitcoinPred\test_data\20251107_191552\interest\interest_rates_test_20251107_1916.csv')
quant = pd.read_csv(r'C:\Users\baile\Documents\Artificial Intelligence\BitcoinPred\test_data\20251107_191552\quant\quant_bitcoin_test_20251107_1915.csv')
google = pd.read_csv(r'C:\Users\baile\Documents\Artificial Intelligence\BitcoinPred\test_data\20251107_191552\sentiment\google_news_sentiment_test_20251107_1916_hours_26280.csv')

# %%
print(f"sentiment is extracted for {len(google['published'].apply(lambda x: x[:16]).unique())} days.")
# Out:
# sentiment is extracted for 25 days.
