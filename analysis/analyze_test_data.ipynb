# %%
import pandas as pd
interest = r'C:\Users\baile\Documents\Artificial Intelligence\BitcoinPred\data\20251108_155202\interest\interest_rates_test_20251108_2335.csv'
quant = r'C:\Users\baile\Documents\Artificial Intelligence\BitcoinPred\data\20251108_155202\quant\quant_bitcoin_test_20251108_1552.csv'
google = r'C:\Users\baile\Documents\Artificial Intelligence\BitcoinPred\data\20251108_155202\sentiment\google_news_sentiment_20251108_2335_days_1095.csv'

# %%
import sys
sys.path.append(r'C:\Users\baile\Documents\Artificial Intelligence\BitcoinPred\main_scripts')
from train import preprocess_data
df = preprocess_data(quant, google, interest)
# Out:
# --- Starting Data Preprocessing with Temporal Alignment ---
# --- Data Preprocessing Complete ---

# %%
df.describe()
# Out:
#           timestamp           open           high            low  \
# count  1.074000e+03    1074.000000    1074.000000    1074.000000
# mean   1.716206e+12   62766.576369   63895.587095   61635.193082
# min    1.669853e+12   16439.980000   16621.000000   16273.400000
# 25%    1.693030e+12   29289.320000   29707.272500   29046.145000
# 50%    1.716206e+12   62104.570000   63420.420000   60661.695000
# 75%    1.739383e+12   95116.980000   96842.500000   93633.902500
# max    1.762560e+12  124723.570000  126296.000000  123115.770000
# std    2.679967e+10   32594.465568   33072.661437   32046.111364
#
#                close        volume           merge_date  domestic_series  \
# count    1074.000000   1074.000000                 1074         1074.000
# mean    62845.825503  12289.885502  2024-05-20 12:00:00            7.577
# min     16439.740000   1227.768033  2022-12-01 00:00:00            7.577
# 25%     29321.770000   5852.254197  2023-08-26 06:00:00            7.577
# ...
